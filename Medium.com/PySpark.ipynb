# %% [markdown]
# ## Data Wrangling with PySpark, for Beginners
#
#
# https://towardsdatascience.com/data-wrangling-with-pyspark-for-beginners-3f2197c81511
#
# Content Credit: Aashish Nair
#
# #### About PySpark:
# - Parallel processing
# - Some reffer as `lazy evaluation/ computing`- only runs when necessary, unlike Pandas
# - Sightly higher learn curve
# - Best for big data
#
# #### Sample Data:
# https://www.kaggle.com/datasets/mathchi/diabetes-data-set

# %%
# Imports 

import pandas as pd
import numpy as np

# %%
# Create PySpark Session

from pyspark.sql import SparkSession

# create a spark session
ss = SparkSession.builder.appName('Test').getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/anaconda3/lib/python3.9/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/06/20 13:28:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# > ### Load Data

# %%
# Load Data pandas

df_pandas = pd.read_csv('diabetes.csv')
df_pandas.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# #### PySpark Load Data

# %%
df_pyspark = ss.read.csv('diabetes.csv', header=True, inferSchema=True)

# %%
# PySpark use the show() function as a trigger (lazy execution)

df_pyspark.show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|
# |          0|    137|           40|           35|    168|43.1|                   2.288| 33|      1|
# |          5|    116|           74|            0|      0|25.6|                   0.201| 30|      0|
# |          3|     78|           50|           32|     88|31.0|                   0.248| 26|      1|
# |         10|    115|            0|            0|      0|35.3|                   0.134| 29|      0|
# |          2|    197|           70|           45|    543|30.5|                   0.158| 53|      1|
# |          8|    125|           96|            0|      0| 0.0|                   0.232| 54|      1|
# |          4|    110|           92|            0|      0|37.6|                   0.191| 30|      0|
# |         10|    168|           74|            0|      0|38.0|                   0.537| 34|      1|
# |         10|    139|           80|            0|      0|27.1|                   1.441| 57|      0|
# |          1|    189|           60|           23|    846|30.1|                   0.398| 59|      1|
# |          5|    166|           72|           19|    175|25.8|                   0.587| 51|      1|
# |          7|    100|            0|            0|      0|30.0|                   0.484| 32|      1|
# |          0|    118|           84|           47|    230|45.8|                   0.551| 31|      1|
# |          7|    107|           74|            0|      0|29.6|                   0.254| 31|      1|
# |          1|    103|           30|           38|     83|43.3|                   0.183| 33|      0|
# |          1|    115|           70|           30|     96|34.6|                   0.529| 32|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# only showing top 20 rows

# %% [markdown]
# #### NOTES:
# By default, PySpark will treat the header as the first row and all columns as string variables. To prevent PySpark from making any false assumptions, the user must assign values to the header and inferSchema parameters.

# %% [markdown]
# > ### Selecting column(s)

# %%
# Selecting columns with Pandas
df_pandas[['Age', 'BMI']].head()
# Out:
#    Age   BMI
# 0   50  33.6
# 1   31  26.6
# 2   32  23.3
# 3   21  28.1
# 4   33  43.1

# %%
df_pandas['Glucose'].head()
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
df_pandas[['Glucose']].head()
# Out:
#    Glucose
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137

# %% [markdown]
# ### PySpark.select

# %%
# Selecting columns with PySpark
df_pyspark.select('Age', 'BMI')
# Out:
# DataFrame[Age: int, BMI: double]

# %%
df_pyspark.select('Age')
# Out:
# DataFrame[Age: int]

# %% [markdown]
# > ### Describe df

# %%
# Pandas

df_pandas.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# PySpark

df_pyspark.describe().show()
# Out:
# +-------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------------+------------------+------------------+
# |summary|       Pregnancies|          Glucose|     BloodPressure|     SkinThickness|           Insulin|               BMI|DiabetesPedigreeFunction|               Age|           Outcome|
# +-------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------------+------------------+------------------+
# |  count|               768|              768|               768|               768|               768|               768|                     768|               768|               768|
# |   mean|3.8450520833333335|     120.89453125|       69.10546875|20.536458333333332| 79.79947916666667|31.992578124999977|      0.4718763020833327|33.240885416666664|0.3489583333333333|
# | stddev|  3.36957806269887|31.97261819513622|19.355807170644777|15.952217567727642|115.24400235133803| 7.884160320375441|       0.331328595012775|11.760231540678689| 0.476951377242799|
# |    min|                 0|                0|                 0|                 0|                 0|               0.0|                   0.078|                21|                 0|
# |    max|                17|              199|               122|                99|               846|              67.1|                    2.42|                81|                 1|
# +-------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------------+------------------+------------------+

# %% [markdown]
# ### NOTES:
# - Pandas includes the percentiles with describe (25th, 50th, 75th), PySpark does not
# - PySpark includes categorical descritions unlike Pandas

# %% [markdown]
# > #### Add Colunns

# %%
# # Pandas

# col = 'BMI'

# df_pandas["BMI_classes"] = np.where(df_pandas[col] < 18.5, 'underweight', 
#                       (np.where((df_pandas[col] > 18.5) & (df_pandas[col] <  24.9)), 'normal'),
#                       (np.where((df_pandas[col] > 25.9) & (df_pandas[col] <  29.9)), 'preobese'),
#                        (np.where((df_pandas[col] >= 30.0)), 'obese'),
#                        (np.where((df_pandas[col] > 30.0) & (df_pandas[col] <  34.9)), 'class_i'),
#                         (np.where((df_pandas[col] > 35.0) & (df_pandas[col] <  39.9)), 'class_ii'),
#                          np.where((df_pandas[col] >= 40.0), 'class_iii'))

# %%
df_pandas['Age_in_10_Years'] = df_pandas['Age'] + 10
df_pandas.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Age_in_10_Years
# 0                     0.627   50        1               60
# 1                     0.351   31        0               41
# 2                     0.672   32        1               42
# 3                     0.167   21        0               31
# 4                     2.288   33        1               43

# %%
# PySpark

df_pyspark = df_pyspark.withColumn('age in 10 years', df_pyspark['age']+10)
df_pyspark.show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+---------------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|age in 10 years|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+---------------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|             60|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|             41|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|             42|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|             31|
# |          0|    137|           40|           35|    168|43.1|                   2.288| 33|      1|             43|
# |          5|    116|           74|            0|      0|25.6|                   0.201| 30|      0|             40|
# |          3|     78|           50|           32|     88|31.0|                   0.248| 26|      1|             36|
# |         10|    115|            0|            0|      0|35.3|                   0.134| 29|      0|             39|
# |          2|    197|           70|           45|    543|30.5|                   0.158| 53|      1|             63|
# |          8|    125|           96|            0|      0| 0.0|                   0.232| 54|      1|             64|
# |          4|    110|           92|            0|      0|37.6|                   0.191| 30|      0|             40|
# |         10|    168|           74|            0|      0|38.0|                   0.537| 34|      1|             44|
# |         10|    139|           80|            0|      0|27.1|                   1.441| 57|      0|             67|
# |          1|    189|           60|           23|    846|30.1|                   0.398| 59|      1|             69|
# |          5|    166|           72|           19|    175|25.8|                   0.587| 51|      1|             61|
# |          7|    100|            0|            0|      0|30.0|                   0.484| 32|      1|             42|
# |          0|    118|           84|           47|    230|45.8|                   0.551| 31|      1|             41|
# |          7|    107|           74|            0|      0|29.6|                   0.254| 31|      1|             41|
# |          1|    103|           30|           38|     83|43.3|                   0.183| 33|      0|             43|
# |          1|    115|           70|           30|     96|34.6|                   0.529| 32|      1|             42|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+---------------+
# only showing top 20 rows

# %% [markdown]
# > ### Remove Columns

# %%
# Pandas
df_pandas = df_pandas.drop('Age_in_10_Years', axis=1)
df_pandas.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
# PySpark

df_pyspark = df_pyspark.drop('age in 10 years')

# %%
df_pyspark.limit(5).show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|
# |          0|    137|           40|           35|    168|43.1|                   2.288| 33|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+

# %% [markdown]
# > ### Remove Missing Values

# %%
# Pandas
df_pandas = df_pandas.dropna()
df_pandas.head(2)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
# PySpark
df_pyspark = df_pyspark.na.drop()
df_pyspark.limit(5).show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|
# |          0|    137|           40|           35|    168|43.1|                   2.288| 33|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+

# %% [markdown]
# > ### Filtering
# Example-- People with pre-obese BMI (25.9 - 29.9)

# %%
# Pandas

df_pandas_preobese = df_pandas[(df_pandas['BMI'] > 25.9) & (df_pandas['BMI'] < 29.9)]
df_pandas_preobese.head()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1             1       85             66             29        0  26.6
# 3             1       89             66             23       94  28.1
# 12           10      139             80              0        0  27.1
# 17            7      107             74              0        0  29.6
# 23            9      119             80             35        0  29.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 1                      0.351   31        0
# 3                      0.167   21        0
# 12                     1.441   57        0
# 17                     0.254   31        1
# 23                     0.263   29        1

# %%
# PySpark Option I

df_pyspark_preobese = df_pyspark[(df_pyspark.BMI > 25.9) & (df_pyspark.BMI < 29.9)]
df_pyspark_preobese.limit(5).show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|
# |         10|    139|           80|            0|      0|27.1|                   1.441| 57|      0|
# |          7|    107|           74|            0|      0|29.6|                   0.254| 31|      1|
# |          9|    119|           80|           35|      0|29.0|                   0.263| 29|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+

# %%
# PySpark Option II

df_pyspark_preobese_ii = df_pyspark.filter(((df_pyspark['BMI'] > 25.9)) & ((df_pyspark['BMI'] < 29.9)))
df_pyspark_preobese_ii.limit(5).show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          1|     89|           66|           23|     94|28.1|                   0.167| 21|      0|
# |         10|    139|           80|            0|      0|27.1|                   1.441| 57|      0|
# |          7|    107|           74|            0|      0|29.6|                   0.254| 31|      1|
# |          9|    119|           80|           35|      0|29.0|                   0.263| 29|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+

# %% [markdown]
# > ### Aggregation

# %%
# Pandas
df_pandas.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# PySpark

df_pyspark.groupby('Outcome').mean().show(vertical = True)
# Out:
# -RECORD 0--------------------------------------------
#  Outcome                       | 1
#  avg(Pregnancies)              | 4.865671641791045
#  avg(Glucose)                  | 141.25746268656715
#  avg(BloodPressure)            | 70.82462686567165
#  avg(SkinThickness)            | 22.16417910447761
#  avg(Insulin)                  | 100.33582089552239
#  avg(BMI)                      | 35.14253731343278
#  avg(DiabetesPedigreeFunction) | 0.5505
#  avg(Age)                      | 37.06716417910448
#  avg(Outcome)                  | 1.0
# -RECORD 1--------------------------------------------
#  Outcome                       | 0
#  avg(Pregnancies)              | 3.298
#  avg(Glucose)                  | 109.98
#  avg(BloodPressure)            | 68.184
#  avg(SkinThickness)            | 19.664
#  avg(Insulin)                  | 68.792
#  avg(BMI)                      | 30.30419999999996
#  avg(DiabetesPedigreeFunction) | 0.42973400000000017
#  avg(Age)                      | 31.19
#  avg(Outcome)                  | 0.0

# %% [markdown]
# > ### Joins

# %%
# Pandas

df_pandas2 = pd.read_csv('diabetes.csv')
df_pandas_join = df_pandas.merge(df_pandas2, on='Pregnancies', how='inner')

# preview of data
df_pandas_join.head()
# Out:
#    Pregnancies  Glucose_x  BloodPressure_x  SkinThickness_x  Insulin_x  BMI_x  \
# 0            6        148               72               35          0   33.6
# 1            6        148               72               35          0   33.6
# 2            6        148               72               35          0   33.6
# 3            6        148               72               35          0   33.6
# 4            6        148               72               35          0   33.6
#
#    DiabetesPedigreeFunction_x  Age_x  Outcome_x  Glucose_y  BloodPressure_y  \
# 0                       0.627     50          1        148               72
# 1                       0.627     50          1         92               92
# 2                       0.627     50          1        144               72
# 3                       0.627     50          1         93               50
# 4                       0.627     50          1        111               64
#
#    SkinThickness_y  Insulin_y  BMI_y  DiabetesPedigreeFunction_y  Age_y  \
# 0               35          0   33.6                       0.627     50
# 1                0          0   19.9                       0.188     28
# 2               27        228   33.9                       0.255     40
# 3               30         64   28.7                       0.356     23
# 4               39          0   34.2                       0.260     24
#
#    Outcome_y
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# PySpark

# join datasets
df_pyspark2 = ss.read.csv('diabetes.csv', header=True, inferSchema=True)
df_pyspark_join = df_pyspark.join(df_pyspark2, on='Pregnancies', how='inner')

# preview of data
df_pyspark_join.show(5, vertical = True)
# Out:
# -RECORD 0-------------------------
#  Pregnancies              | 6
#  Glucose                  | 148
#  BloodPressure            | 72
#  SkinThickness            | 35
#  Insulin                  | 0
#  BMI                      | 33.6
#  DiabetesPedigreeFunction | 0.627
#  Age                      | 50
#  Outcome                  | 1
#  Glucose                  | 190
#  BloodPressure            | 92
#  SkinThickness            | 0
#  Insulin                  | 0
#  BMI                      | 35.5
#  DiabetesPedigreeFunction | 0.278
#  Age                      | 66
#  Outcome                  | 1
# -RECORD 1-------------------------
#  Pregnancies              | 6
#  Glucose                  | 148
#  BloodPressure            | 72
#  SkinThickness            | 35
#  Insulin                  | 0
#  BMI                      | 33.6
#  DiabetesPedigreeFunction | 0.627
#  Age                      | 50
#  Outcome                  | 1
#  Glucose                  | 162
#  BloodPressure            | 62
#  SkinThickness            | 0
#  Insulin                  | 0
#  BMI                      | 24.3
#  DiabetesPedigreeFunction | 0.178
#  Age                      | 50
#  Outcome                  | 1
# -RECORD 2-------------------------
#  Pregnancies              | 6
#  Glucose                  | 148
#  BloodPressure            | 72
#  SkinThickness            | 35
#  Insulin                  | 0
#  BMI                      | 33.6
#  DiabetesPedigreeFunction | 0.627
#  Age                      | 50
#  Outcome                  | 1
#  Glucose                  | 80
#  BloodPressure            | 80
#  SkinThickness            | 36
#  Insulin                  | 0
#  BMI                      | 39.8
#  DiabetesPedigreeFunction | 0.177
#  Age                      | 28
#  Outcome                  | 0
# -RECORD 3-------------------------
#  Pregnancies              | 6
#  Glucose                  | 148
#  BloodPressure            | 72
#  SkinThickness            | 35
#  Insulin                  | 0
#  BMI                      | 33.6
#  DiabetesPedigreeFunction | 0.627
#  Age                      | 50
#  Outcome                  | 1
#  Glucose                  | 125
#  BloodPressure            | 78
#  SkinThickness            | 31
#  Insulin                  | 0
#  BMI                      | 27.6
#  DiabetesPedigreeFunction | 0.565
#  Age                      | 49
#  Outcome                  | 1
# -RECORD 4-------------------------
#  Pregnancies              | 6
#  Glucose                  | 148
#  BloodPressure            | 72
#  SkinThickness            | 35
#  Insulin                  | 0
#  BMI                      | 33.6
#  DiabetesPedigreeFunction | 0.627
#  Age                      | 50
#  Outcome                  | 1
#  Glucose                  | 195
#  BloodPressure            | 70
#  SkinThickness            | 0
#  Insulin                  | 0
#  BMI                      | 30.9
#  DiabetesPedigreeFunction | 0.328
#  Age                      | 31
#  Outcome                  | 1
# only showing top 5 rows

# %% [markdown]
# > ### Converting Joined Pyspark Frame to Pandas DF

# %%
df_in_pandas  = df_pyspark_join.toPandas()
df_in_pandas.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            6      148             72             35        0  33.6
# 2            6      148             72             35        0  33.6
# 3            6      148             72             35        0  33.6
# 4            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome  Glucose  BloodPressure  \
# 0                     0.627   50        1      190             92
# 1                     0.627   50        1      162             62
# 2                     0.627   50        1       80             80
# 3                     0.627   50        1      125             78
# 4                     0.627   50        1      195             70
#
#    SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0              0        0  35.5                     0.278   66        1
# 1              0        0  24.3                     0.178   50        1
# 2             36        0  39.8                     0.177   28        0
# 3             31        0  27.6                     0.565   49        1
# 4              0        0  30.9                     0.328   31        1

# %% [markdown]
# ## Pros and Cons
#
# - PySpark does not support row indexing
# - PySpark bugs are hard to find
# - Visualizations not possible with PySpark (convert to Pandas df `.toPandas`)
