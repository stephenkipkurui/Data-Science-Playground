# %% [markdown]
# # SQL For Data Science
#
# SQL - Structured Query Language

# %% [markdown]
# DATABASE - organize large data to be retrieved quickly
#
# Relational Database - (From relational algebra)

# %%
from get_data import*
from libraries import*

# %%
df = acquire_data()
df
# Out:
# Reading from CSV..
#     market_date market_day  market_week  market_year market_start_time  \
# 0    2019-03-02   Saturday            9         2019           8:00 AM
# 1    2019-03-09   Saturday           10         2019           9:00 AM
# 2    2019-03-13  Wednesday           11         2019           4:00 PM
# 3    2019-03-16   Saturday           11         2019           8:00 AM
# 4    2019-03-20  Wednesday           12         2019           4:00 PM
# ..          ...        ...          ...          ...               ...
# 145  2020-09-26   Saturday           39         2020           8:00 AM
# 146  2020-09-30  Wednesday           40         2020           4:00 PM
# 147  2020-10-03   Saturday           40         2020           8:00 AM
# 148  2020-10-07  Wednesday           41         2020           4:00 PM
# 149  2020-10-10   Saturday           41         2020           8:00 AM
#
#     market_end_time  special_notes      market_season  market_min_temp  \
# ...

# %%
season_year = df.loc[:, ['market_season', 'market_year', 'market_min_temp', 'market_day']]

# %%
sns.barplot(data =season_year, y = 'market_min_temp', x= 'market_season' )
None

# %%
sns.barplot(data =season_year, y = 'market_min_temp', x= 'market_day' )
None

# %%
sns.boxplot(data =season_year, y = 'market_min_temp', x= 'market_day' )
None

# %%
sns.violinplot(data =season_year, y = 'market_min_temp', x= 'market_day' )
None

# %%
df.iloc[:, [3, 4]]
# Out:
#      market_year market_start_time
# 0           2019           8:00 AM
# 1           2019           9:00 AM
# 2           2019           4:00 PM
# 3           2019           8:00 AM
# 4           2019           4:00 PM
# ..           ...               ...
# 145         2020           8:00 AM
# 146         2020           4:00 PM
# 147         2020           8:00 AM
# 148         2020           4:00 PM
# 149         2020           8:00 AM
#
# [150 rows x 2 columns]
